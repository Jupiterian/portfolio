# %% [raw]
# ---
# layout: post
# title: Mathematical Expressions Homework
# permalink: /penguins/js-lessons/homework/math-expressions
# categories: [JavaScript, Homework]
# author: Ishan Jha
# ---

# %% [markdown]
# # Penguins JS Lessons
#
# <a href="https://github.com/Comp-Sci-Team/js-lesson_pages/blob/main/_notebooks/CSSE/JavaScriptLessons/Mathematic_Expressions/2025-09-30-penguins-math-exp-hw.ipynb" download><b>Download Homework</b></a> <br/>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSfwgZR0QYAg_uYuZ7XqqEm-xlU0-gZFE2dtgnKEe5kH7Yp0Vg/viewform?usp=dialog"><b>Submission Google Form for Homework</b></a>
#
# ## **Mathematical Expressions Homework**
# In order to learn this subject of programming well, you have to practice:
#
# > Popcorn hack 1: operations with variables
#
# > Popcorn hack 2: Make 2 variables `x`, and `y`. Compute 3 different operations and log it into the console with console.log();
#
# > Final Task: Build a system of functions that represent different mathematical expressions. Each of these functions will perform a different mathematical operation(ex: add, subtract). Make at least 5 of these different functions.
#
# ---

# %% [markdown]
# ## <b>Popcorn Hack 1 (Progress Check)</b>
#
# <b>Part 1:</b><br/>
# In the javascript node below, make 2 variables, `num1` set to 6 and `num2` set to 3, then write the equation `(num1 * num2) + (num1 / 2)`.
#
# The output should be 21.<br/>
# <br/>
# <b>Part 2:</b><br/>
# Next, keeping the same variables, add a new variable called `total` that is equal to the equation `num1 / num2 + 2 ** 3`, and this time make the equation<br/><br/> `(total + 15) - numb1 ** 2 / 4` <br/><br/>
#
# Write this code below:

# %%
# %%javascript
# // put your popcorn hack 1 code here:
# let num1 = 6;
# let num2 = 3;
# let answer = (num1 * num2) + (num1/2);
# console.log(answer);
#
# //part 2
# let total = num1/num2 + 2 ** 3;
# let equation = (total + 15) - num1 ** 2 / 4
# console.log(equation);

# %% [markdown]
# ---
#
# ## Popcorn Hack 2 (Progress check):
#
# Create 2 variables `x` and `y`. With the output area below, provide 3 different operators used with the 2 variables<br/>(`ex: let sum = x + y;`)<br/> and fill in the output with a sentence that provides all three operators and their respective answer.

# %%
# %%html
#
# <h3>Popcorn hack 2 output</h3>
# <div id="homework1"></div>
# <script>
# (() => {
#     // Your variables go here
#     let x = 3;
#     let y = 4;
#
# 	// put your operations here:
# 	// feel free to do any operation and change the names of the variables
# 	let operation1 = x + y;
# 	let operation2 = x - y;
# 	let operation3 = x % y;
#
#     // Put the answer for the 3 operators in this DOM element
#     document.getElementById("homework1").innerText =
#       `Sum: ${operation1}\nDifference: ${operation2}\nRemainder: ${operation3}`;
#
#     // also log to console for debugging
#     console.log('Popcorn hack 2 results:', operation1, operation2, operation3);
# })();
# </script>
# Out:
# <h3>Popcorn hack 2 output</h3>
# <div id="homework1"></div>
# <script>
# (() => {
#     // Your variables go here
#     let x = 3;
#     let y = 4;
#
# 	// put your operations here:
# 	// feel free to do any operation and change the names of the variables
# 	let operation1 = x + y;
# 	let operation2 = x - y;
# 	let operation3 = x % y;
#
#     // Put the answer for the 3 operators in this DOM element
#     document.getElementById("homework1").innerText =
#       `Sum: ${operation1}\nDifference: ${operation2}\nRemainder: ${operation3}`;
#
#     // also log to console for debugging
#     console.log('Popcorn hack 2 results:', operation1, operation2, operation3);
# })();
# </script>

# %% [markdown]
# ---
#
# ## Final Task:
#
# 1. Make 5 different functions, each with different operators/expressions:
#
# - Addition
# - Subtraction
# - Multiplication
# - Exponential
# - Modulus
#
# 2. Be able to use the functions as well as <code>document.getElementById</code> to make the buttons output the result.
#
# 3. Have fun! Mess around with different variables with different values, and maybe see if you can make any complex equations like the ones you're learning in your math class. The end objective is for you to be able to use and understand math expressions.
#
#
# ### Example function:
#
# ```
# function add(a, b)
# {
# 	return a + b;
# }
# ```
#
# ### Some ideas you can use:
# - Multiply Function
# - Square root function
# - Cube root function
#
# ---

# %% [markdown]
# Now that you have seen the example, you will start writing your custom functions in the html code block below: <br>
# <u> Make sure to follow each comment on where to write your code, don't modify any existing code. </u>
# <br><br>

# %%
# %%html
#
# <!-- This is where the outputs of your functions will go: -->
# <h2>Function outputs:</h2>
#
# <!-- Primary 5 functions (already present) -->
# <button type="button" onclick="Add(4,5)">Function Output 1 (Add)</button>
# <div id="functionOutput1"></div>
# <br>
#
# <button type="button" onclick="Subtract(9,4)">Function Output 2 (Subtract)</button>
# <div id="functionOutput2"></div>
# <br>
#
# <button type="button" onclick="Multiply(4,5)">Function Output 3 (Multiply)</button>
# <div id="functionOutput3"></div>
# <br>
#
# <button type="button" onclick="Divide(20,5)">Function Output 4 (Divide)</button>
# <div id="functionOutput4"></div>
# <br>
#
# <button type="button" onclick="Modulus(11,3)">Function Output 5 (Modulus)</button>
# <div id="functionOutput5"></div>
# <br>
#
# <!-- TEN additional functions -->
# <button type="button" onclick="Power(2,8)">Function Output 6 (Power: 2^8)</button>
# <div id="functionOutput6"></div>
# <br>
#
# <button type="button" onclick="Square(7)">Function Output 7 (Square: 7²)</button>
# <div id="functionOutput7"></div>
# <br>
#
# <button type="button" onclick="Cube(3)">Function Output 8 (Cube: 3³)</button>
# <div id="functionOutput8"></div>
# <br>
#
# <button type="button" onclick="Sqrt(49)">Function Output 9 (Sqrt: √49)</button>
# <div id="functionOutput9"></div>
# <br>
#
# <button type="button" onclick="Cuberoot(27)">Function Output 10 (Cuberoot: ∛27)</button>
# <div id="functionOutput10"></div>
# <br>
#
# <button type="button" onclick="Floor(4.7)">Function Output 11 (Floor: ⌊4.7⌋)</button>
# <div id="functionOutput11"></div>
# <br>
#
# <button type="button" onclick="Ceil(4.1)">Function Output 12 (Ceil: ⌈4.1⌉)</button>
# <div id="functionOutput12"></div>
# <br>
#
# <button type="button" onclick="Abs(-12)">Function Output 13 (Abs: |-12|)</button>
# <div id="functionOutput13"></div>
# <br>
#
# <button type="button" onclick="GCD(48,18)">Function Output 14 (GCD: gcd(48,18))</button>
# <div id="functionOutput14"></div>
# <br>
#
# <button type="button" onclick="LCM(4,6)">Function Output 15 (LCM: lcm(4,6))</button>
# <div id="functionOutput15"></div>
# <br>
#
# <!-- You will write the code for your functions in this script area  -->
# <script>
# 	// Example function (implemented)
# 	function Add(a,b){
# 		let result = a + b;
# 		document.getElementById("functionOutput1").innerText = result;
# 	}
#
# 	// Subtract function
# 	function Subtract(a,b){
# 		let result = a - b;
# 		document.getElementById("functionOutput2").innerText = result;
# 	}
#
# 	// Multiply function
# 	function Multiply(a,b){
# 		let result = a * b;
# 		document.getElementById("functionOutput3").innerText = result;
# 	}
#
# 	// Divide function (handles divide-by-zero)
# 	function Divide(a,b){
# 		let result;
# 		if(b === 0){
# 			result = 'Error: divide by 0';
# 		} else {
# 			result = a / b;
# 		}
# 		document.getElementById("functionOutput4").innerText = result;
# 	}
#
# 	// Modulus function
# 	function Modulus(a,b){
# 		let result = a % b;
# 		document.getElementById("functionOutput5").innerText = result;
# 	}
#
# 	// --- Additional 10 functions ---
# 	function Power(a,b){
# 		let result = a ** b;
# 		document.getElementById("functionOutput6").innerText = result;
# 	}
#
# 	function Square(a){
# 		let result = a * a;
# 		document.getElementById("functionOutput7").innerText = result;
# 	}
#
# 	function Cube(a){
# 		let result = a * a * a;
# 		document.getElementById("functionOutput8").innerText = result;
# 	}
#
# 	function Sqrt(a){
# 		let result = Math.sqrt(a);
# 		document.getElementById("functionOutput9").innerText = result;
# 	}
#
# 	function Cuberoot(a){
# 		let result = Math.cbrt ? Math.cbrt(a) : Math.pow(a, 1/3);
# 		document.getElementById("functionOutput10").innerText = result;
# 	}
#
# 	function Floor(a){
# 		let result = Math.floor(a);
# 		document.getElementById("functionOutput11").innerText = result;
# 	}
#
# 	function Ceil(a){
# 		let result = Math.ceil(a);
# 		document.getElementById("functionOutput12").innerText = result;
# 	}
#
# 	function Abs(a){
# 		let result = Math.abs(a);
# 		document.getElementById("functionOutput13").innerText = result;
# 	}
#
# 	// helper gcd
# 	function gcd(a,b){
# 		a = Math.abs(a); b = Math.abs(b);
# 		while(b){
# 			let t = b; b = a % b; a = t;
# 		}
# 		return a;
# 	}
#
# 	function GCD(a,b){
# 		let result = gcd(a,b);
# 		document.getElementById("functionOutput14").innerText = result;
# 	}
#
# 	function LCM(a,b){
# 		if(a === 0 || b === 0){
# 			document.getElementById("functionOutput15").innerText = 0; return;
# 		}
# 		let result = Math.abs(a * b) / gcd(a,b);
# 		document.getElementById("functionOutput15").innerText = result;
# 	}
#
# 	// Example template you can copy/edit later
# 	function ExpressionExample() {
# 		let a = 2, b = 3;
# 		let result = (a + b) * (a ** 2);
# 		console.log('ExpressionExample ->', result);
# 	}
# </script>
# Out:
# <!-- This is where the outputs of your functions will go: -->
# <h2>Function outputs:</h2>
#
# <!-- Primary 5 functions (already present) -->
# <button type="button" onclick="Add(4,5)">Function Output 1 (Add)</button>
# <div id="functionOutput1"></div>
# <br>
#
# <button type="button" onclick="Subtract(9,4)">Function Output 2 (Subtract)</button>
# <div id="functionOutput2"></div>
# <br>
#
# <button type="button" onclick="Multiply(4,5)">Function Output 3 (Multiply)</button>
# <div id="functionOutput3"></div>
# <br>
#
# <button type="button" onclick="Divide(20,5)">Function Output 4 (Divide)</button>
# <div id="functionOutput4"></div>
# <br>
#
# <button type="button" onclick="Modulus(11,3)">Function Output 5 (Modulus)</button>
# <div id="functionOutput5"></div>
# <br>
#
# <!-- TEN additional functions -->
# <button type="button" onclick="Power(2,8)">Function Output 6 (Power: 2^8)</button>
# <div id="functionOutput6"></div>
# <br>
#
# <button type="button" onclick="Square(7)">Function Output 7 (Square: 7²)</button>
# <div id="functionOutput7"></div>
# <br>
#
# <button type="button" onclick="Cube(3)">Function Output 8 (Cube: 3³)</button>
# <div id="functionOutput8"></div>
# <br>
#
# <button type="button" onclick="Sqrt(49)">Function Output 9 (Sqrt: √49)</button>
# <div id="functionOutput9"></div>
# <br>
#
# <button type="button" onclick="Cuberoot(27)">Function Output 10 (Cuberoot: ∛27)</button>
# <div id="functionOutput10"></div>
# <br>
#
# <button type="button" onclick="Floor(4.7)">Function Output 11 (Floor: ⌊4.7⌋)</button>
# <div id="functionOutput11"></div>
# <br>
#
# <button type="button" onclick="Ceil(4.1)">Function Output 12 (Ceil: ⌈4.1⌉)</button>
# <div id="functionOutput12"></div>
# <br>
#
# <button type="button" onclick="Abs(-12)">Function Output 13 (Abs: |-12|)</button>
# <div id="functionOutput13"></div>
# <br>
#
# <button type="button" onclick="GCD(48,18)">Function Output 14 (GCD: gcd(48,18))</button>
# <div id="functionOutput14"></div>
# <br>
#
# <button type="button" onclick="LCM(4,6)">Function Output 15 (LCM: lcm(4,6))</button>
# <div id="functionOutput15"></div>
# <br>
#
# <!-- You will write the code for your functions in this script area  -->
# <script>
# 	// Example function (implemented)
# 	function Add(a,b){
# 		let result = a + b;
# 		document.getElementById("functionOutput1").innerText = result;
# 	}
#
# 	// Subtract function
# 	function Subtract(a,b){
# 		let result = a - b;
# 		document.getElementById("functionOutput2").innerText = result;
# 	}
#
# 	// Multiply function
# 	function Multiply(a,b){
# 		let result = a * b;
# 		document.getElementById("functionOutput3").innerText = result;
# 	}
#
# 	// Divide function (handles divide-by-zero)
# 	function Divide(a,b){
# 		let result;
# 		if(b === 0){
# 			result = 'Error: divide by 0';
# 		} else {
# 			result = a / b;
# 		}
# 		document.getElementById("functionOutput4").innerText = result;
# 	}
#
# 	// Modulus function
# 	function Modulus(a,b){
# 		let result = a % b;
# 		document.getElementById("functionOutput5").innerText = result;
# 	}
#
# 	// --- Additional 10 functions ---
# 	function Power(a,b){
# 		let result = a ** b;
# 		document.getElementById("functionOutput6").innerText = result;
# 	}
#
# 	function Square(a){
# 		let result = a * a;
# 		document.getElementById("functionOutput7").innerText = result;
# 	}
#
# 	function Cube(a){
# 		let result = a * a * a;
# 		document.getElementById("functionOutput8").innerText = result;
# 	}
#
# 	function Sqrt(a){
# 		let result = Math.sqrt(a);
# 		document.getElementById("functionOutput9").innerText = result;
# 	}
#
# 	function Cuberoot(a){
# 		let result = Math.cbrt ? Math.cbrt(a) : Math.pow(a, 1/3);
# 		document.getElementById("functionOutput10").innerText = result;
# 	}
#
# 	function Floor(a){
# 		let result = Math.floor(a);
# 		document.getElementById("functionOutput11").innerText = result;
# 	}
#
# 	function Ceil(a){
# 		let result = Math.ceil(a);
# 		document.getElementById("functionOutput12").innerText = result;
# 	}
#
# 	function Abs(a){
# 		let result = Math.abs(a);
# 		document.getElementById("functionOutput13").innerText = result;
# 	}
#
# 	// helper gcd
# 	function gcd(a,b){
# 		a = Math.abs(a); b = Math.abs(b);
# 		while(b){
# 			let t = b; b = a % b; a = t;
# 		}
# 		return a;
# 	}
#
# 	function GCD(a,b){
# 		let result = gcd(a,b);
# 		document.getElementById("functionOutput14").innerText = result;
# 	}
#
# 	function LCM(a,b){
# 		if(a === 0 || b === 0){
# 			document.getElementById("functionOutput15").innerText = 0; return;
# 		}
# 		let result = Math.abs(a * b) / gcd(a,b);
# 		document.getElementById("functionOutput15").innerText = result;
# 	}
#
# 	// Example template you can copy/edit later
# 	function ExpressionExample() {
# 		let a = 2, b = 3;
# 		let result = (a + b) * (a ** 2);
# 		console.log('ExpressionExample ->', result);
# 	}
# </script>

# %% [markdown]
# ---
#
# <b>Grading</b>
#
# Popcorn Hack 1: Completion gives 0.2 points.<br/><br/>
# Popcorn Hack 2: Completion gives 0.3 points.<br/><br/>
#
# Final Task: Completion gives 0.5 points. Max of 0.02 extra points from extra work relevant to the subject or finishing assignment in a way that shows exceptional comprehension of the lesson.
#
# <br>
# <b><u>Make sure to submit your homework deployed link onto the global homework submission google sheet</u><b>

# %% [markdown]
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSfwgZR0QYAg_uYuZ7XqqEm-xlU0-gZFE2dtgnKEe5kH7Yp0Vg/viewform?usp=dialog"><b>Submission Google Form for Homework</b></a>
