# %% [raw]
# ---
# layout: post
# title: UESL 3.1 Homework
# author: Ishan Jha
# permalink: /homework/3-1/
# ---

# %% [markdown]
# ## POPCORN
# ```python
# # stars is 8
# stars = 8
# #checkpoint = 8
# checkpoint_stars = stars
# # stars is 12
# stars = stars + 4
# print(stars)
# print(checkpoint_stars)
# ```
# # Prediction. Stars = 12. checkpoint_stars = 8. Reasoning: Because stars starts out at 8 and then checkpoint_stars copies it and creates a new variable with value 8. Then stars is modified later and is given a new value of 8+4 = 12.

# %% [raw]
# ## MCQ
# 1. B. Explanation: given we can see quotes, we can assume it is a string
# 2. A. Explanation: checkpoint ← stars means checkpoint is being set to an equivalent value of stars. Given in the previous line stars is equal to 8, checkpoint must also be equal to 8.
# 3. C. Explanation: In pseudocode, ← is the ap operator. The other two are used in python.
# 4. B. Explanation: In the code line that reassigns the value in a new value. This is best demonstrated by B.

# %% [raw]
# # Homework
#
# ```python
# level_one_stars = 12
# level_two_stars = 18
# level_three_stars = 10
#
# original_total = level_one_stars + level_two_stars + level_three_stars
# print(game_name)
# print(reduced_motion)
# print(original_total)
#
# # Add a bonus to level two and compare the stored total with a fresh calculation.
# bonus = 5
# stored_total = original_total
# updated_total = stored_total + bonus
# print(stored_total)
# print(updated_total)
#
# # Predictions and actual results.
# predicted_original_total = 40
# predicted_updated_total = 45
# print("Predicted original total:", predicted_original_total)
# print("Actual original total:", original_total)
# print("Predicted updated total:", predicted_updated_total)
# print("Actual updated total:", updated_total)
#
# # Restart the bonus and confirm all three totals return to 40.
# bonus = 0
# restarted_stored_total = original_total
# restarted_updated_total = restarted_stored_total + bonus
# restarted_recalculated_total = level_one_stars + level_two_stars + level_three_stars + bonus
# print(restarted_stored_total)
# print(restarted_updated_total)
# print(restarted_recalculated_total)
# assert (restarted_stored_total, restarted_updated_total, restarted_recalculated_total) == (40, 40, 40)
#
# # Design-thinking note:
# # Need: A player may need a comfortable way to play without distracting motion.
# # Goal: Make motion adjustable so more players can enjoy the game.
# # Considered: A settings toggle represented by a Boolean, reduced_motion = True or False.
# # Prototype: This notebook uses the Boolean to record the player's reduced-motion choice.
# # Test/revision: Test both Boolean values in the settings flow and keep motion reduced
# # when True; revise the prototype if any animation ignores the selected setting.
# # Reduced motion should be a player choice because comfort, attention, and accessibility
# # vary from person to person; the player should control the experience.
# ```
