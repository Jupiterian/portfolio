# %% [raw]
# ---
# layout: post
# title: UESL 3.1 Homework
# author: Ishan Jha
# permalink: /homework/3-2/
# ---

# %% [markdown]
# # A. Popcorn Hack 1
# Predictions in comments
# ```python
# level_stars = [10, 20, 15]
# # the following line will output 10. I know this because it is iterating for the 1st object at index 0 of the level_stars list.
# print(level_stars[0])
# # the following line will output 20. I know this because it is iterating for the 2nd object at index 1 of the level_stars list.
# print(level_stars[1])
# # the following line will output 3. This is because level_stars has 3 objects and thus is of length 3.
# print(len(level_stars))
# ```

# %% [markdown]
# # B. Popcorn Hack 2
# Prediction: The AP index 2 selects the same second level as the python index 1.
#
# ## Run and Change.
# After changing the append value from 5 to 8, the new list will be [9, 9, 12, 8], with the new object 8 being added and the object at index 1 being changed from 6 to 9.
# ```python
# level_stars = [6, 9, 12]
# level_stars[1] = level_stars[1] + 3
# level_stars.append(8)
# print(level_stars)
# print(len(level_stars))
# ```
# ```
# level_stars ← [6, 9, 12] // Create three levels' star counts.
# level_stars[2] ← level_stars[2] + 3 // Add three stars to the second level; AP starts at 1.
# APPEND(level_stars, 8) // Add a fourth level with five stars.
# DISPLAY(level_stars) // Show all counts: [6, 12, 12, 5].
# DISPLAY(LENGTH(level_stars)) // Show the new level count: 4.
# ```

# %% [markdown]
# # MCQ Check
# Record A, B or C for each before revealing the key.
#
# Which AP index selects the first level? A 0 · B 1 · C the list length. B because AP starts at one.
# Replacing one count changes the list length by: A 0 · B 1 · C −1. A because replacing the index doesn't change the list length.
# What does APPEND(level_stars, 5) do? A Change level five · B Add five levels · C Add one element with value 5. C because append adds an element of value 5.
# Why use a list plus traversal for 100 levels? A It always runs faster · B It avoids a separate variable and sum edit for every level · C It prevents all errors. B - lists compress multiple different variable values into one list.

# %% [raw]
# # Homework
#
# **Cell 8 (Markdown):**
# ```markdown
# ## Design-Thinking Reflection
#
# | Phase | What We Did |
# |-------|-----------|
# | **Prototype** | Started with index access in sections A & B: `level_stars[0]`, `level_stars[1]` |
# | **Actual test** | Verified our predictions about indexing; hand-calculated sums for small lists |
# | **Revision 1** | Noticed that for 100 levels, manual summation was error-prone and tedious |
# | **Representation refined** | Adopted one list + a `for` loop traversal to compute totals automatically |
# | **Result** | Scalable design: works for 3 levels or 100 levels with identical code |
#
# ### Suggestion for Better UX
# Players and makers shouldn't have to think in indices. Consider adding **level labels** alongside the star counts:
#
# ```python
# level_names = ["Forest", "Castle", "Mountain", "Sky"]
# level_stars = [12, 23, 10, 7]
#
# for i in range(len(level_names)):
#     print(f"{level_names[i]}: {level_stars[i]} stars")
